# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_churn_dataset.csv")

# %%
df_label = df.copy()

# %%
le = LabelEncoder()
df_label['Gender_encoded'] = le.fit_transform(df_label['gender'])

# %%
print('\n Label Encoded data')
print(df_label[['Gender_encoded','age']])
# Out:
#  Label Encoded data
#       Gender_encoded  age
# 0                  0   54
# 1                  2   33
# 2                  1   38
# 3                  0   22
# 4                  2   29
# ...              ...  ...
# 7995               2   44
# 7996               1   34
# 7997               0   17
# 7998               0   34
# 7999               2   45
#
# [8000 rows x 2 columns]

# %%
from pandas import get_dummies
df_encoded = pd.get_dummies(df, columns=['subscription_type'])

# %%
print('\n One- Hot Encoded Data')
print(df_encoded.head())
# Out:
#  One- Hot Encoded Data
#    user_id  gender  age country  listening_time  songs_played_per_day  \
# 0        1  Female   54      CA              26                    23
# 1        2   Other   33      DE             141                    62
# 2        3    Male   38      AU             199                    38
# 3        4  Female   22      CA              36                     2
# 4        5   Other   29      US             250                    57
#
#    skip_rate device_type  ads_listened_per_week  offline_listening  \
# 0       0.20     Desktop                     31                  0
# 1       0.34         Web                      0                  1
# 2       0.04      Mobile                      0                  1
# 3       0.31      Mobile                      0                  1
# 4       0.36      Mobile                      0                  1
#
#    is_churned  subscription_type_Family  subscription_type_Free  \
# 0           1                     False                    True
# 1           0                      True                   False
# 2           1                     False                   False
# 3           0                     False                   False
# 4           1                      True                   False
#
#    subscription_type_Premium  subscription_type_Student
# 0                      False                      False
# 1                      False                      False
# 2                       True                      False
# 3                      False                       True
# 4                      False                      False
